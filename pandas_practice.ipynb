# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('pokemon_data.csv', index_col = 0)

# %%
dataset
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df = pd.DataFrame(dataset)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(dataset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dataset.head(10)
# Out:
#                         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                  Bulbasaur  Grass  Poison  45      49       49       65
# 2                    Ivysaur  Grass  Poison  60      62       63       80
# 3                   Venusaur  Grass  Poison  80      82       83      100
# 3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                 Charmander   Fire     NaN  39      52       43       60
# 5                 Charmeleon   Fire     NaN  58      64       58       80
# 6                  Charizard   Fire  Flying  78      84       78      109
# 6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# ...

# %%
dataset.isnull().head(10)
# Out:
#     Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1  False   False   False  False   False    False    False    False  False
# 2  False   False   False  False   False    False    False    False  False
# 3  False   False   False  False   False    False    False    False  False
# 3  False   False   False  False   False    False    False    False  False
# 4  False   False    True  False   False    False    False    False  False
# 5  False   False    True  False   False    False    False    False  False
# 6  False   False   False  False   False    False    False    False  False
# 6  False   False   False  False   False    False    False    False  False
# 6  False   False   False  False   False    False    False    False  False
# 7  False   False    True  False   False    False    False    False  False
#
#    Generation  Legendary
# #
# 1       False      False
# 2       False      False
# 3       False      False
# 3       False      False
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 69.5+ KB

# %%
dataset.shape
# Out:
# (800, 11)

# %%
dataset = dataset.drop_duplicates()

# %%
dataset.head(10)
# Out:
#                         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                  Bulbasaur  Grass  Poison  45      49       49       65
# 2                    Ivysaur  Grass  Poison  60      62       63       80
# 3                   Venusaur  Grass  Poison  80      82       83      100
# 3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                 Charmander   Fire     NaN  39      52       43       60
# 5                 Charmeleon   Fire     NaN  58      64       58       80
# 6                  Charizard   Fire  Flying  78      84       78      109
# 6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# ...

# %%
dataset.shape
# Out:
# (800, 11)

# %%
dataset = dataset.append(dataset)

# %%
dataset.shape
# Out:
# (1600, 11)

# %%
dataset.drop_duplicates(inplace = True)

# %%
dataset.shape
# Out:
# (800, 11)

# %%
dataset.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dataset.rename(columns = {
    'Sp.Atk' : 'SA',
    'Sp.Def' : 'SD'
    
}, inplace = True)

# %%
dataset.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dataset.columns = [col.lower() for col in dataset]

# %%
type(dataset.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
dataset.head()
# Out:
#                     name type 1  type 2  hp  attack  defense  sp. atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    sp. def  speed  generation  legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dataset.isnull().sum()
# Out:
# name            0
# type 1          0
# type 2        386
# hp              0
# attack          0
# defense         0
# sp. atk         0
# sp. def         0
# speed           0
# generation      0
# legendary       0
# dtype: int64

# %%
type2 = dataset['type 2']

# %%
type2.head()
# Out:
# #
# 1    Poison
# 2    Poison
# 3    Poison
# 3    Poison
# 4       NaN
# Name: type 2, dtype: object

# %%
type2.fillna('Notype', inplace = True)

# %%
dataset.head(10)
# Out:
#                         name type 1  type 2  hp  attack  defense  sp. atk  \
# #
# 1                  Bulbasaur  Grass  Poison  45      49       49       65
# 2                    Ivysaur  Grass  Poison  60      62       63       80
# 3                   Venusaur  Grass  Poison  80      82       83      100
# 3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                 Charmander   Fire  Notype  39      52       43       60
# 5                 Charmeleon   Fire  Notype  58      64       58       80
# 6                  Charizard   Fire  Flying  78      84       78      109
# 6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 7                   Squirtle  Water  Notype  44      48       65       50
#
#    sp. def  speed  generation  legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# ...

# %%
dataset.isnull().sum()
# Out:
# name          0
# type 1        0
# type 2        0
# hp            0
# attack        0
# defense       0
# sp. atk       0
# sp. def       0
# speed         0
# generation    0
# legendary     0
# dtype: int64

# %%
dataset.describe()
# Out:
#                hp      attack     defense     sp. atk     sp. def       speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
dataset['type 1'].describe()
# Out:
# count       800
# unique       18
# top       Water
# freq        112
# Name: type 1, dtype: object

# %%
dataset['type 1'].value_counts().head(21)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: type 1, dtype: int64

# %%
data_corr = dataset.corr()

# %%
dataset.nlargest(n=10, columns = 'attack')
# Out:
#                         name   type 1    type 2   hp  attack  defense  \
# #
# 150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 386       DeoxysAttack Forme  Psychic    Notype   50     180       20
# 445    GarchompMega Garchomp   Dragon    Ground  108     170      115
# 646       KyuremBlack Kyurem   Dragon       Ice  125     170      100
# 354      BanetteMega Banette    Ghost    Notype   64     165       75
# 409                Rampardos     Rock    Notype   97     165       60
# 475      GalladeMega Gallade  Psychic  Fighting   68     165       95
#
#      sp. atk  sp. def  speed  generation  legendary
# #
# 150      154      100    130           1       True
# 214       40      105     75           2      False
# ...

# %%
data_corr.nlargest(n=10, columns = 'legendary')
# Out:
#                   hp    attack   defense   sp. atk   sp. def     speed  \
# legendary   0.273620  0.345408  0.246377  0.448907  0.363937  0.326715
# sp. atk     0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# sp. def     0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# attack      0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# speed       0.175952  0.381240  0.015227  0.473018  0.259133  1.000000
# hp          1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# defense     0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# generation  0.058683  0.051451  0.042419  0.036437  0.028486 -0.023121
#
#             generation  legendary
# legendary     0.079794   1.000000
# sp. atk       0.036437   0.448907
# sp. def       0.028486   0.363937
# attack        0.051451   0.345408
# speed        -0.023121   0.326715
# hp            0.058683   0.273620
# defense       0.042419   0.246377
# generation    1.000000   0.079794

# %%
dataset[['type 1', 'type 2']].head(7)
# Out:
#   type 1  type 2
# #
# 1  Grass  Poison
# 2  Grass  Poison
# 3  Grass  Poison
# 3  Grass  Poison
# 4   Fire  Notype
# 5   Fire  Notype
# 6   Fire  Flying

# %%
dataset.loc[1:4]  #Extracting Rows using Slicing, "loc" includes the value after ":" as well
# Out:
#                     name type 1  type 2  hp  attack  defense  sp. atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire  Notype  39      52       43       60
#
#    sp. def  speed  generation  legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
condition = dataset['type 1'] == 'Ghost'

# %%
condition.tail(20)
# Out:
# #
# 710     True
# 710     True
# 710     True
# 710     True
# 711     True
# 711     True
# 711     True
# 711     True
# 712    False
# 713    False
# 714    False
# 715    False
# 716    False
# 717    False
# 718    False
# 719    False
# 719    False
# 720    False
# 720    False
# 721    False
# Name: type 1, dtype: bool

# %%
dataset.loc[(dataset['type 1'] == 'Ghost') & (dataset['type 2'] == 'Poison')].head()
# Out:
#                  name type 1  type 2  hp  attack  defense  sp. atk  sp. def  \
# #
# 92             Gastly  Ghost  Poison  30      35       30      100       35
# 93            Haunter  Ghost  Poison  45      50       45      115       55
# 94             Gengar  Ghost  Poison  60      65       60      130       75
# 94  GengarMega Gengar  Ghost  Poison  60      65       80      170       95
#
#     speed  generation  legendary
# #
# 92     80           1      False
# 93     95           1      False
# 94    110           1      False
# 94    130           1      False

# %%
dataset.loc[dataset['type 1'].isin(['Ghost', 'Water'])].tail(15)
# Out:
#                       name type 1  type 2  hp  attack  defense  sp. atk  \
# #
# 656                Froakie  Water  Notype  41      56       40       62
# 657              Frogadier  Water  Notype  54      63       52       83
# 658               Greninja  Water    Dark  72      95       67      103
# 692              Clauncher  Water  Notype  50      53       62       58
# 693              Clawitzer  Water  Notype  71      73       88      120
# 708               Phantump  Ghost   Grass  43      70       48       50
# 709              Trevenant  Ghost   Grass  85     110       76       65
# 710  PumpkabooAverage Size  Ghost   Grass  49      66       70       44
# 710    PumpkabooSmall Size  Ghost   Grass  44      66       70       44
# 710    PumpkabooLarge Size  Ghost   Grass  54      66       70       44
# 710    PumpkabooSuper Size  Ghost   Grass  59      66       70       44
# 711  GourgeistAverage Size  Ghost   Grass  65      90      122       58
# ...

# %%
sns.heatmap(dataset.corr(), annot = True)
plt.show()
